# %% [markdown]
# # Module 3 Project Final Submission
# This is an assignment and a fictional case study by Alex Shropshire and Mia Iseman. U.S. Health and Human Services is not actually involved in any way. We do work with actual publicly available data.
# <a> href= "Repository URL" <\a>
# Presentation URL

# %% [markdown]
# # Goal: Identify which U.S. counties are at risk of having a very high overdose fatality rate based on factors related to education and internet connectivity.

# %% [markdown]
# # Process
# 1. Understand the business needs.
# 2. Understand the data.
# 3. Prepare the data for analysis and modeling.
# 4. Model
# 5. Evaluate Results
# 6. Deploy

# %% [markdown]
# # Business Understanding
#
# The U.S. Department of Health and Human Services has a number of partnerships with businesses and other governmental agencies to address public health concerns. Since we are in the middle of an opioid epidemic, it is necessary to discover whether there is an opportunity to form a partnership that prevents overdose fatalities.
#
# Before they can prevent overdoses, they need to do their due diligence to discover the deep underlying factors behind an overdose fatality. As part of this research, we have been tasked with investigating the relationship between overdose fatality rates at the county level based on county education and internet connectivity data.
#
# We will deliver a model that predicts whether a county will have a high overdose rate or not, so that more attention can be paid to those counties that are at risk of having the highest overdose rates in the country. This information will be combined with several other investigations and efforts in order to determine the best course of action in overdose prevention programming.

# %% [markdown]
# # Data Understanding
#
# Our research and models do not imply a casual relationship (in either direction). High or low fatal overdose rate is our target feature.  Education/internet connectivity may <i>predict</i> our target, but they don't <i>cause</i> our target. This is another reason that this model and research should be taken with regard to several other datasets and models in order to understand the best way to predict AND prevent overdoses.
#
# We constructed our target from the <a href="https://wonder.cdc.gov/"> Center for Disease Control's Wonder</a>, a database querying tool.
#
# Facts about our target variable, the Crude Death Rate:
# * Deaths from 2013-2017
# * Grouped by U.S. County for U.S. States
# * Drug and Alcohol-related <i>fatalities</i>
# * Per 100,000 people
# * Some counties had suppressed or unreliable data.
#
# We construct our features from the U.S. Census American Community Survey <a href="https://www.census.gov/programs-surveys/acs/about.html">5-year 2013-2017 survey</a>.

# %% [markdown]
# # Data Preparation
#
# ## Retrieve and prep the Census data (features)
# We will begin with the Census data. We retrieve it using <a href="https://github.com/ljwolf/cenpy/blob/master/README.rst">Cenpy</a>, "an interface to explore and query the US Census API and return Pandas Dataframes."

# %%
import pandas as pd
import cenpy as c
#find dataframe of available surveys 
available = c.explorer.available()
#find survey containing ACS and year 2017
acs_df = available[available['title'].str.contains('ACS') == True]
acs_df = acs_df[acs_df['vintage'] == 2017]
acs_df.head()
# Out:
#              variable_cell_limit                                    title  \
# ACSDT1Y2017                  NaN               ACS 1-Year Detailed Tables
# ACSCP1Y2017                  NaN           ACS 1-Year Comparison Profiles
# ACSDP1Y2017                  NaN                 ACS 1-Year Data Profiles
# ACSSPP1Y2017                 NaN  ACS 1-Year Selected Population Profiles
# ACSST1Y2017                  NaN                ACS 1-Year Subject Tables
#
#                   temporal spatial           publisher programCode  \
# ACSDT1Y2017   unidentified     NaN  U.S. Census Bureau     006:004
# ACSCP1Y2017   unidentified     NaN  U.S. Census Bureau     006:004
# ACSDP1Y2017   unidentified     NaN  U.S. Census Bureau     006:004
# ACSSPP1Y2017  unidentified     NaN  U.S. Census Bureau     006:004
# ACSST1Y2017   unidentified     NaN  U.S. Census Bureau     006:004
#
#                            modified keyword  \
# ACSDT1Y2017   2018-09-13 00:00:00.0      ()
# ACSCP1Y2017   2018-09-13 00:00:00.0      ()
# ACSDP1Y2017   2018-09-13 00:00:00.0      ()
# ACSSPP1Y2017  2018-09-17 00:00:00.0      ()
# ACSST1Y2017   2018-09-13 00:00:00.0      ()
#
#                                                    distribution  \
# ACSDT1Y2017   {'@type': 'dcat:Distribution', 'accessURL': 'h...
# ACSCP1Y2017   {'@type': 'dcat:Distribution', 'accessURL': 'h...
# ACSDP1Y2017   {'@type': 'dcat:Distribution', 'accessURL': 'h...
# ACSSPP1Y2017  {'@type': 'dcat:Distribution', 'accessURL': 'h...
# ACSST1Y2017   {'@type': 'dcat:Distribution', 'accessURL': 'h...
#
#                                                     description  ... c_isCube  \
# ACSDT1Y2017   The American Community Survey (ACS) is an ongo...  ...     True
# ACSCP1Y2017   The American Community Survey (ACS) is an ongo...  ...     True
# ACSDP1Y2017   The American Community Survey (ACS) is an ongo...  ...     True
# ACSSPP1Y2017  Selected Population Profiles provide broad soc...  ...     True
# ACSST1Y2017   The American Community Survey (ACS) is an ongo...  ...     True
#
#               c_isAvailable c_isAggregate  \
# ACSDT1Y2017            True          True
# ACSCP1Y2017            True          True
# ACSDP1Y2017            True          True
# ACSSPP1Y2017           True          True
# ACSST1Y2017            True          True
#
#                                                    c_groupsLink  \
# ACSDT1Y2017   https://api.census.gov/data/2017/acs/acs1/grou...
# ACSCP1Y2017   https://api.census.gov/data/2017/acs/acs1/cpro...
# ACSDP1Y2017   https://api.census.gov/data/2017/acs/acs1/prof...
# ACSSPP1Y2017  https://api.census.gov/data/2017/acs/acs1/spp/...
# ACSST1Y2017   https://api.census.gov/data/2017/acs/acs1/subj...
#
#                                                 c_geographyLink  \
# ACSDT1Y2017   https://api.census.gov/data/2017/acs/acs1/geog...
# ACSCP1Y2017   https://api.census.gov/data/2017/acs/acs1/cpro...
# ACSDP1Y2017   https://api.census.gov/data/2017/acs/acs1/prof...
# ACSSPP1Y2017  https://api.census.gov/data/2017/acs/acs1/spp/...
# ACSST1Y2017   https://api.census.gov/data/2017/acs/acs1/subj...
#
#                                                  c_examplesLink  \
# ACSDT1Y2017   https://api.census.gov/data/2017/acs/acs1/exam...
# ACSCP1Y2017   https://api.census.gov/data/2017/acs/acs1/cpro...
# ACSDP1Y2017   https://api.census.gov/data/2017/acs/acs1/prof...
# ACSSPP1Y2017  https://api.census.gov/data/2017/acs/acs1/spp/...
# ACSST1Y2017   https://api.census.gov/data/2017/acs/acs1/subj...
#
#                           c_dataset  c.is_cell_limit_discovery bureauCode  \
# ACSDT1Y2017             (acs, acs1)                        NaN        NaN
# ACSCP1Y2017   (acs, acs1, cprofile)                        NaN        NaN
# ACSDP1Y2017    (acs, acs1, profile)                        NaN        NaN
# ACSSPP1Y2017       (acs, acs1, spp)                        NaN        NaN
# ACSST1Y2017    (acs, acs1, subject)                        NaN        NaN
#
#              accessLevel
# ACSDT1Y2017          NaN
# ACSCP1Y2017          NaN
# ACSDP1Y2017          NaN
# ACSSPP1Y2017         NaN
# ACSST1Y2017          NaN
#
# [5 rows x 26 columns]

# %%
c.explorer.explain('ACSDP5Y2017')
#this is it!
# Out:
# {'ACS 5-Year Data Profiles': 'The American Community Survey (ACS) is an ongoing survey that provides data every year -- giving communities the current information they need to plan investments and services. The ACS covers a broad range of topics about social, economic, demographic, and housing characteristics of the U.S. population. The data profiles include the following geographies: nation, all states (including DC and Puerto Rico), all metropolitan areas, all congressional districts, all counties, all places and all tracts. Data profiles contain broad social, economic, housing, and demographic information. The data are presented as both counts and percentages. There are over 2,400 variables in this dataset.'}

# %%
#connect to the survey data
con = c.base.Connection('ACSDP5Y2017')
#create a geographical unit of county 
g_unit = 'county:*'

# %% [markdown]
# Now we need to know how which variables serve our business needs. Looking at https://api.census.gov/data/2017/acs/acs5/profile/variables.html and the "search" feature, we can find about 15 and write the code below to make the list.

# %%
#create education feature columns
cols_edu = [] 
for n in range(52,68): 
    var_name = 'DP02_00'+str(n)+'PE'
    cols_edu.append(var_name)

#create internet feature columns
cols_internet = []
for n in range(150,153):
    var_name = 'DP02_0'+str(n)+'PE'
    cols_internet.append(var_name)

#retreieve the name of the county (row) so we can join them later
cols_req = ['NAME']

cols = cols_req + cols_edu + cols_internet

# %%
#query the census data and retrieve as a dataframe 
counties_df = con.query(cols=cols, geo_unit=g_unit)
counties_df.head().T
# Out:
#                                    0                       1  \
# NAME         Pickens County, Alabama  Sumter County, Alabama
# DP02_0052PE                     4416                    4106
# DP02_0053PE                     11.8                     4.4
# DP02_0054PE                      5.7                     5.9
# DP02_0055PE                     39.2                    26.9
# DP02_0056PE                     26.8                    18.8
# DP02_0057PE                     16.5                    44.1
# DP02_0058PE                    14241                    8244
# DP02_0059PE                      6.2                     4.7
# DP02_0060PE                     13.9                    12.6
# DP02_0061PE                     37.8                    39.7
# DP02_0062PE                     22.8                    17.7
# DP02_0063PE                      7.5                     7.0
# DP02_0064PE                      8.8                    10.6
# DP02_0065PE                      3.0                     7.6
# DP02_0066PE                     79.8                    82.7
# DP02_0067PE                     11.8                    18.2
# DP02_0150PE                     7620                    5073
# DP02_0151PE                     71.0                    64.8
# DP02_0152PE                     60.9                    50.4
# state                             01                      01
# county                           107                     119
#
#                                      2                        3  \
# NAME         Jefferson County, Alabama  Choctaw County, Alabama
# DP02_0052PE                     165739                     2718
# DP02_0053PE                        6.8                      3.9
# DP02_0054PE                        5.7                      4.3
# DP02_0055PE                       39.9                     48.0
# DP02_0056PE                       20.5                     24.4
# DP02_0057PE                       27.1                     19.4
# DP02_0058PE                     447048                     9449
# DP02_0059PE                        3.0                      6.6
# DP02_0060PE                        7.6                     13.3
# DP02_0061PE                       26.8                     39.9
# DP02_0062PE                       22.6                     19.5
# DP02_0063PE                        8.1                      9.1
# DP02_0064PE                       19.4                      7.9
# DP02_0065PE                       12.5                      3.8
# DP02_0066PE                       89.4                     80.1
# DP02_0067PE                       31.9                     11.6
# DP02_0150PE                     261390                     5463
# DP02_0151PE                       84.4                     70.4
# DP02_0152PE                       73.0                     52.3
# state                               01                       01
# county                             073                      023
#
#                                     4
# NAME         Franklin County, Alabama
# DP02_0052PE                      7426
# DP02_0053PE                       3.3
# DP02_0054PE                       6.8
# DP02_0055PE                      49.2
# DP02_0056PE                      23.3
# DP02_0057PE                      17.4
# DP02_0058PE                     20734
# DP02_0059PE                      11.8
# DP02_0060PE                      11.9
# DP02_0061PE                      37.5
# DP02_0062PE                      18.0
# DP02_0063PE                       7.5
# DP02_0064PE                       8.3
# DP02_0065PE                       5.1
# DP02_0066PE                      76.4
# DP02_0067PE                      13.4
# DP02_0150PE                     11533
# DP02_0151PE                      74.2
# DP02_0152PE                      60.3
# state                              01
# county                            059

# %%
#rename the columns so we know what they are referencing
counties_df = counties_df.rename(index=str, columns={'NAME': 'county_name', 
                                       'DP02_0052PE': '%_inschool_3+',
                                       'DP02_0053PE': '%_preschool_3+',
                                       'DP02_0054PE': '%_kinderg_3+',
                                       'DP02_0055PE': '%_elementary_3+',
                                       'DP02_0056PE': '%_highschool_3+',
                                       'DP02_0057PE': '%_college_3+',
                                       'DP02_0058PE': '%_25+',
                                       'DP02_0059PE': '%_below9th_25+',
                                       'DP02_0060PE': '%_9th-12th_25+',
                                       'DP02_0061PE': '%_hsgrad_25+',
                                       'DP02_0062PE': '%_somecollege_25+',
                                       'DP02_0063PE': '%_associates_25+',
                                       'DP02_0064PE': '%_bachelors_b25+',
                                       'DP02_0065PE': '%_gradschool_25+',
                                       'DP02_0066PE': '%_hsgrad_or+_25+',
                                       'DP02_0067PE': '%_bachelors_or+_25+',
                                       'DP02_0150PE': '%_useinternet_total_households',
                                       'DP02_0151PE': '%_havecomp_total_households',
                                       'DP02_0152PE': '%_broadband_total_households',
                                      })

# %%
counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3220 entries, 0 to 3219
# Data columns (total 22 columns):
# county_name                       3220 non-null object
# %_inschool_3+                     3142 non-null object
# %_preschool_3+                    3142 non-null object
# %_kinderg_3+                      3142 non-null object
# %_elementary_3+                   3142 non-null object
# %_highschool_3+                   3142 non-null object
# %_college_3+                      3142 non-null object
# %_25+                             3142 non-null object
# %_below9th_25+                    3142 non-null object
# %_9th-12th_25+                    3142 non-null object
# %_hsgrad_25+                      3142 non-null object
# %_somecollege_25+                 3142 non-null object
# %_associates_25+                  3142 non-null object
# %_bachelors_b25+                  3142 non-null object
# %_gradschool_25+                  3142 non-null object
# %_hsgrad_or+_25+                  3142 non-null object
# %_bachelors_or+_25+               3142 non-null object
# %_useinternet_total_households    3142 non-null object
# %_havecomp_total_households       3142 non-null object
# %_broadband_total_households      3142 non-null object
# state                             3220 non-null object
# county                            3220 non-null object
# dtypes: object(22)
# memory usage: 578.6+ KB

# %%
#investigate the blank rows 
counties_df[pd.isnull(counties_df).any(axis=1)]
# Out:
#                                county_name %_inschool_3+ %_preschool_3+  \
# 3142         Jayuya Municipio, Puerto Rico          None           None
# 3143   Quebradillas Municipio, Puerto Rico          None           None
# 3144        Guayama Municipio, Puerto Rico          None           None
# 3145        Guánica Municipio, Puerto Rico          None           None
# 3146         Rincón Municipio, Puerto Rico          None           None
# 3147       Villalba Municipio, Puerto Rico          None           None
# 3148   Aguas Buenas Municipio, Puerto Rico          None           None
# 3149        Bayamón Municipio, Puerto Rico          None           None
# 3150    Hormigueros Municipio, Puerto Rico          None           None
# 3151         Manatí Municipio, Puerto Rico          None           None
# 3152        Naguabo Municipio, Puerto Rico          None           None
# 3153        Humacao Municipio, Puerto Rico          None           None
# 3154     Juana Díaz Municipio, Puerto Rico          None           None
# 3155          Coamo Municipio, Puerto Rico          None           None
# 3156         Dorado Municipio, Puerto Rico          None           None
# 3157           Moca Municipio, Puerto Rico          None           None
# 3158          Lares Municipio, Puerto Rico          None           None
# 3159    Las Piedras Municipio, Puerto Rico          None           None
# 3160     Río Grande Municipio, Puerto Rico          None           None
# 3161       San Juan Municipio, Puerto Rico          None           None
# 3162        Culebra Municipio, Puerto Rico          None           None
# 3163         Gurabo Municipio, Puerto Rico          None           None
# 3164        Salinas Municipio, Puerto Rico          None           None
# 3165    Barceloneta Municipio, Puerto Rico          None           None
# 3166      Vega Alta Municipio, Puerto Rico          None           None
# 3167      Vega Baja Municipio, Puerto Rico          None           None
# 3168          Loíza Municipio, Puerto Rico          None           None
# 3169      Naranjito Municipio, Puerto Rico          None           None
# 3170       Carolina Municipio, Puerto Rico          None           None
# 3171  San Sebastián Municipio, Puerto Rico          None           None
# ...                                    ...           ...            ...
# 3190     Guayanilla Municipio, Puerto Rico          None           None
# 3191      Aguadilla Municipio, Puerto Rico          None           None
# 3192      Cabo Rojo Municipio, Puerto Rico          None           None
# 3193        Fajardo Municipio, Puerto Rico          None           None
# 3194         Juncos Municipio, Puerto Rico          None           None
# 3195          Lajas Municipio, Puerto Rico          None           None
# 3196  Sabana Grande Municipio, Puerto Rico          None           None
# 3197     Las Marías Municipio, Puerto Rico          None           None
# 3198       Patillas Municipio, Puerto Rico          None           None
# 3199          Cayey Municipio, Puerto Rico          None           None
# 3200     San Germán Municipio, Puerto Rico          None           None
# 3201         Utuado Municipio, Puerto Rico          None           None
# 3202        Corozal Municipio, Puerto Rico          None           None
# 3203        Maunabo Municipio, Puerto Rico          None           None
# 3204       Peñuelas Municipio, Puerto Rico          None           None
# 3205        Arecibo Municipio, Puerto Rico          None           None
# 3206         Arroyo Municipio, Puerto Rico          None           None
# 3207        Yabucoa Municipio, Puerto Rico          None           None
# 3208         Aguada Municipio, Puerto Rico          None           None
# 3209   Santa Isabel Municipio, Puerto Rico          None           None
# 3210  Trujillo Alto Municipio, Puerto Rico          None           None
# 3211         Caguas Municipio, Puerto Rico          None           None
# 3212      Canóvanas Municipio, Puerto Rico          None           None
# 3213          Cidra Municipio, Puerto Rico          None           None
# 3214       Adjuntas Municipio, Puerto Rico          None           None
# 3215          Camuy Municipio, Puerto Rico          None           None
# 3216          Ponce Municipio, Puerto Rico          None           None
# 3217         Cataño Municipio, Puerto Rico          None           None
# 3218        Florida Municipio, Puerto Rico          None           None
# 3219        Hatillo Municipio, Puerto Rico          None           None
#
#      %_kinderg_3+ %_elementary_3+ %_highschool_3+ %_college_3+ %_25+  \
# 3142         None            None            None         None  None
# 3143         None            None            None         None  None
# 3144         None            None            None         None  None
# 3145         None            None            None         None  None
# 3146         None            None            None         None  None
# 3147         None            None            None         None  None
# 3148         None            None            None         None  None
# 3149         None            None            None         None  None
# 3150         None            None            None         None  None
# 3151         None            None            None         None  None
# 3152         None            None            None         None  None
# 3153         None            None            None         None  None
# 3154         None            None            None         None  None
# 3155         None            None            None         None  None
# 3156         None            None            None         None  None
# 3157         None            None            None         None  None
# 3158         None            None            None         None  None
# 3159         None            None            None         None  None
# 3160         None            None            None         None  None
# 3161         None            None            None         None  None
# 3162         None            None            None         None  None
# 3163         None            None            None         None  None
# 3164         None            None            None         None  None
# 3165         None            None            None         None  None
# 3166         None            None            None         None  None
# 3167         None            None            None         None  None
# 3168         None            None            None         None  None
# 3169         None            None            None         None  None
# 3170         None            None            None         None  None
# 3171         None            None            None         None  None
# ...           ...             ...             ...          ...   ...
# 3190         None            None            None         None  None
# 3191         None            None            None         None  None
# 3192         None            None            None         None  None
# 3193         None            None            None         None  None
# 3194         None            None            None         None  None
# 3195         None            None            None         None  None
# 3196         None            None            None         None  None
# 3197         None            None            None         None  None
# 3198         None            None            None         None  None
# 3199         None            None            None         None  None
# 3200         None            None            None         None  None
# 3201         None            None            None         None  None
# 3202         None            None            None         None  None
# 3203         None            None            None         None  None
# 3204         None            None            None         None  None
# 3205         None            None            None         None  None
# 3206         None            None            None         None  None
# 3207         None            None            None         None  None
# 3208         None            None            None         None  None
# 3209         None            None            None         None  None
# 3210         None            None            None         None  None
# 3211         None            None            None         None  None
# 3212         None            None            None         None  None
# 3213         None            None            None         None  None
# 3214         None            None            None         None  None
# 3215         None            None            None         None  None
# 3216         None            None            None         None  None
# 3217         None            None            None         None  None
# 3218         None            None            None         None  None
# 3219         None            None            None         None  None
#
#      %_below9th_25+ %_9th-12th_25+  ... %_associates_25+ %_bachelors_b25+  \
# 3142           None           None  ...             None             None
# 3143           None           None  ...             None             None
# 3144           None           None  ...             None             None
# 3145           None           None  ...             None             None
# 3146           None           None  ...             None             None
# 3147           None           None  ...             None             None
# 3148           None           None  ...             None             None
# 3149           None           None  ...             None             None
# 3150           None           None  ...             None             None
# 3151           None           None  ...             None             None
# 3152           None           None  ...             None             None
# 3153           None           None  ...             None             None
# 3154           None           None  ...             None             None
# 3155           None           None  ...             None             None
# 3156           None           None  ...             None             None
# 3157           None           None  ...             None             None
# 3158           None           None  ...             None             None
# 3159           None           None  ...             None             None
# 3160           None           None  ...             None             None
# 3161           None           None  ...             None             None
# 3162           None           None  ...             None             None
# 3163           None           None  ...             None             None
# 3164           None           None  ...             None             None
# 3165           None           None  ...             None             None
# 3166           None           None  ...             None             None
# 3167           None           None  ...             None             None
# 3168           None           None  ...             None             None
# 3169           None           None  ...             None             None
# 3170           None           None  ...             None             None
# 3171           None           None  ...             None             None
# ...             ...            ...  ...              ...              ...
# 3190           None           None  ...             None             None
# 3191           None           None  ...             None             None
# 3192           None           None  ...             None             None
# 3193           None           None  ...             None             None
# 3194           None           None  ...             None             None
# 3195           None           None  ...             None             None
# 3196           None           None  ...             None             None
# 3197           None           None  ...             None             None
# 3198           None           None  ...             None             None
# 3199           None           None  ...             None             None
# 3200           None           None  ...             None             None
# 3201           None           None  ...             None             None
# 3202           None           None  ...             None             None
# 3203           None           None  ...             None             None
# 3204           None           None  ...             None             None
# 3205           None           None  ...             None             None
# 3206           None           None  ...             None             None
# 3207           None           None  ...             None             None
# 3208           None           None  ...             None             None
# 3209           None           None  ...             None             None
# 3210           None           None  ...             None             None
# 3211           None           None  ...             None             None
# 3212           None           None  ...             None             None
# 3213           None           None  ...             None             None
# 3214           None           None  ...             None             None
# 3215           None           None  ...             None             None
# 3216           None           None  ...             None             None
# 3217           None           None  ...             None             None
# 3218           None           None  ...             None             None
# 3219           None           None  ...             None             None
#
#      %_gradschool_25+ %_hsgrad_or+_25+ %_bachelors_or+_25+  \
# 3142             None             None                None
# 3143             None             None                None
# 3144             None             None                None
# 3145             None             None                None
# 3146             None             None                None
# 3147             None             None                None
# 3148             None             None                None
# 3149             None             None                None
# 3150             None             None                None
# 3151             None             None                None
# 3152             None             None                None
# 3153             None             None                None
# 3154             None             None                None
# 3155             None             None                None
# 3156             None             None                None
# 3157             None             None                None
# 3158             None             None                None
# 3159             None             None                None
# 3160             None             None                None
# 3161             None             None                None
# 3162             None             None                None
# 3163             None             None                None
# 3164             None             None                None
# 3165             None             None                None
# 3166             None             None                None
# 3167             None             None                None
# 3168             None             None                None
# 3169             None             None                None
# 3170             None             None                None
# 3171             None             None                None
# ...               ...              ...                 ...
# 3190             None             None                None
# 3191             None             None                None
# 3192             None             None                None
# 3193             None             None                None
# 3194             None             None                None
# 3195             None             None                None
# 3196             None             None                None
# 3197             None             None                None
# 3198             None             None                None
# 3199             None             None                None
# 3200             None             None                None
# 3201             None             None                None
# 3202             None             None                None
# 3203             None             None                None
# 3204             None             None                None
# 3205             None             None                None
# 3206             None             None                None
# 3207             None             None                None
# 3208             None             None                None
# 3209             None             None                None
# 3210             None             None                None
# 3211             None             None                None
# 3212             None             None                None
# 3213             None             None                None
# 3214             None             None                None
# 3215             None             None                None
# 3216             None             None                None
# 3217             None             None                None
# 3218             None             None                None
# 3219             None             None                None
#
#      %_useinternet_total_households %_havecomp_total_households  \
# 3142                           None                        None
# 3143                           None                        None
# 3144                           None                        None
# 3145                           None                        None
# 3146                           None                        None
# 3147                           None                        None
# 3148                           None                        None
# 3149                           None                        None
# 3150                           None                        None
# 3151                           None                        None
# 3152                           None                        None
# 3153                           None                        None
# 3154                           None                        None
# 3155                           None                        None
# 3156                           None                        None
# 3157                           None                        None
# 3158                           None                        None
# 3159                           None                        None
# 3160                           None                        None
# 3161                           None                        None
# 3162                           None                        None
# 3163                           None                        None
# 3164                           None                        None
# 3165                           None                        None
# 3166                           None                        None
# 3167                           None                        None
# 3168                           None                        None
# 3169                           None                        None
# 3170                           None                        None
# 3171                           None                        None
# ...                             ...                         ...
# 3190                           None                        None
# 3191                           None                        None
# 3192                           None                        None
# 3193                           None                        None
# 3194                           None                        None
# 3195                           None                        None
# 3196                           None                        None
# 3197                           None                        None
# 3198                           None                        None
# 3199                           None                        None
# 3200                           None                        None
# 3201                           None                        None
# 3202                           None                        None
# 3203                           None                        None
# 3204                           None                        None
# 3205                           None                        None
# 3206                           None                        None
# 3207                           None                        None
# 3208                           None                        None
# 3209                           None                        None
# 3210                           None                        None
# 3211                           None                        None
# 3212                           None                        None
# 3213                           None                        None
# 3214                           None                        None
# 3215                           None                        None
# 3216                           None                        None
# 3217                           None                        None
# 3218                           None                        None
# 3219                           None                        None
#
#      %_broadband_total_households state county
# 3142                         None    72    073
# 3143                         None    72    115
# 3144                         None    72    057
# 3145                         None    72    055
# 3146                         None    72    117
# 3147                         None    72    149
# 3148                         None    72    007
# 3149                         None    72    021
# 3150                         None    72    067
# 3151                         None    72    091
# 3152                         None    72    103
# 3153                         None    72    069
# 3154                         None    72    075
# 3155                         None    72    043
# 3156                         None    72    051
# 3157                         None    72    099
# 3158                         None    72    081
# 3159                         None    72    085
# 3160                         None    72    119
# 3161                         None    72    127
# 3162                         None    72    049
# 3163                         None    72    063
# 3164                         None    72    123
# 3165                         None    72    017
# 3166                         None    72    143
# 3167                         None    72    145
# 3168                         None    72    087
# 3169                         None    72    105
# 3170                         None    72    031
# 3171                         None    72    131
# ...                           ...   ...    ...
# 3190                         None    72    059
# 3191                         None    72    005
# 3192                         None    72    023
# 3193                         None    72    053
# 3194                         None    72    077
# 3195                         None    72    079
# 3196                         None    72    121
# 3197                         None    72    083
# 3198                         None    72    109
# 3199                         None    72    035
# 3200                         None    72    125
# 3201                         None    72    141
# 3202                         None    72    047
# 3203                         None    72    095
# 3204                         None    72    111
# 3205                         None    72    013
# 3206                         None    72    015
# 3207                         None    72    151
# 3208                         None    72    003
# 3209                         None    72    133
# 3210                         None    72    139
# 3211                         None    72    025
# 3212                         None    72    029
# 3213                         None    72    041
# 3214                         None    72    001
# 3215                         None    72    027
# 3216                         None    72    113
# 3217                         None    72    033
# 3218                         None    72    054
# 3219                         None    72    065
#
# [78 rows x 22 columns]

# %%
#remove the empty puerto rico counties
counties_df = counties_df.dropna()
counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3142 entries, 0 to 3141
# Data columns (total 22 columns):
# county_name                       3142 non-null object
# %_inschool_3+                     3142 non-null object
# %_preschool_3+                    3142 non-null object
# %_kinderg_3+                      3142 non-null object
# %_elementary_3+                   3142 non-null object
# %_highschool_3+                   3142 non-null object
# %_college_3+                      3142 non-null object
# %_25+                             3142 non-null object
# %_below9th_25+                    3142 non-null object
# %_9th-12th_25+                    3142 non-null object
# %_hsgrad_25+                      3142 non-null object
# %_somecollege_25+                 3142 non-null object
# %_associates_25+                  3142 non-null object
# %_bachelors_b25+                  3142 non-null object
# %_gradschool_25+                  3142 non-null object
# %_hsgrad_or+_25+                  3142 non-null object
# %_bachelors_or+_25+               3142 non-null object
# %_useinternet_total_households    3142 non-null object
# %_havecomp_total_households       3142 non-null object
# %_broadband_total_households      3142 non-null object
# state                             3142 non-null object
# county                            3142 non-null object
# dtypes: object(22)
# memory usage: 564.6+ KB

# %% [markdown]
# This dataframe of 3142 counties is usable for now. We may come back and change things after we see how our CDC data aligns with it.
#
# ## Retrieve and prepare the CDC data (target)
# Our dataset is small enough to download as a file.

# %%
od = pd.read_csv('2013-2017 Overdose Information.txt', delimiter='\t')
od.head()
# Out:
#   Notes              County  County Code Deaths Population  Crude Rate  \
# 0   NaN  Autauga County, AL       1001.0     47     276908     16.9731
# 1   NaN  Baldwin County, AL       1003.0    253    1020551     24.7905
# 2   NaN  Barbour County, AL       1005.0     15     131687  Unreliable
# 3   NaN     Bibb County, AL       1007.0     27     112912     23.9124
# 4   NaN   Blount County, AL       1009.0     88     288981     30.4518
#
#   % of Total Deaths
# 0           0.0103%
# 1           0.0554%
# 2           0.0033%
# 3           0.0059%
# 4           0.0193%

# %%
#notes column just has references we don't need
od = od.drop(['Notes'], axis=1)

# %%
od.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3225 entries, 0 to 3224
# Data columns (total 6 columns):
# County               3147 non-null object
# County Code          3147 non-null float64
# Deaths               3148 non-null object
# Population           3148 non-null object
# Crude Rate           3148 non-null object
# % of Total Deaths    3148 non-null object
# dtypes: float64(1), object(5)
# memory usage: 151.2+ KB

# %%
od['Crude Rate'].unique
# Out:
# <bound method Series.unique of 0          16.9731
# 1          24.7905
# 2       Unreliable
# 3          23.9124
# 4          30.4518
# 5       Suppressed
# 6       Unreliable
# 7          22.8528
# 8          20.0098
# 9          30.8449
# 10         19.1054
# 11      Suppressed
# 12      Unreliable
# 13      Unreliable
# 14      Unreliable
# 15         15.2250
# 16         14.3312
# 17      Unreliable
# 18      Suppressed
# 19         12.7534
# 20      Unreliable
# 21         35.9123
# 22         17.7860
# 23         14.2114
# 24         31.2039
# 25         14.0110
# 26         49.2898
# 27         31.0175
# 28         26.3296
# 29         25.3241
#            ...
# 3195           NaN
# 3196           NaN
# 3197           NaN
# 3198           NaN
# 3199           NaN
# 3200           NaN
# 3201           NaN
# 3202           NaN
# 3203           NaN
# 3204           NaN
# 3205           NaN
# 3206           NaN
# 3207           NaN
# 3208           NaN
# 3209           NaN
# 3210           NaN
# 3211           NaN
# 3212           NaN
# 3213           NaN
# 3214           NaN
# 3215           NaN
# 3216           NaN
# 3217           NaN
# 3218           NaN
# 3219           NaN
# 3220           NaN
# 3221           NaN
# 3222           NaN
# 3223           NaN
# 3224           NaN
# Name: Crude Rate, Length: 3225, dtype: object>

# %%
#we can't use suppressed, unreliable, missing or nan values
od = od.drop(od[od['Crude Rate']=='Suppressed'].index)
od = od.drop(od[od['Crude Rate']=='Unreliable'].index)
od = od.drop(od[od['Deaths']=='Missing'].index)
od = od.drop(od[od['Deaths'].isna()].index)
#there is one county code that is the total at the bottom that we need to drop too
od_reliable = od.drop(od[od['County Code'].isna()].index)

# %%
od_reliable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2016 entries, 0 to 3144
# Data columns (total 6 columns):
# County               2016 non-null object
# County Code          2016 non-null float64
# Deaths               2016 non-null object
# Population           2016 non-null object
# Crude Rate           2016 non-null object
# % of Total Deaths    2016 non-null object
# dtypes: float64(1), object(5)
# memory usage: 110.2+ KB

# %% [markdown]
# Now we have 2016 counties with usable data.
#
# ## Joining the target with the features
#
# To label our data for our classification task, we need to join the two tables. We'll join them on the county code, which is a combination of the state and county in the case of the Census features.

# %%
counties_df['county_code'] = counties_df['state'] + counties_df['county']
counties_df.head(3).T
# Out:
#                                                       0  \
# county_name                     Pickens County, Alabama
# %_inschool_3+                                      4416
# %_preschool_3+                                     11.8
# %_kinderg_3+                                        5.7
# %_elementary_3+                                    39.2
# %_highschool_3+                                    26.8
# %_college_3+                                       16.5
# %_25+                                             14241
# %_below9th_25+                                      6.2
# %_9th-12th_25+                                     13.9
# %_hsgrad_25+                                       37.8
# %_somecollege_25+                                  22.8
# %_associates_25+                                    7.5
# %_bachelors_b25+                                    8.8
# %_gradschool_25+                                    3.0
# %_hsgrad_or+_25+                                   79.8
# %_bachelors_or+_25+                                11.8
# %_useinternet_total_households                     7620
# %_havecomp_total_households                        71.0
# %_broadband_total_households                       60.9
# state                                                01
# county                                              107
# county_code                                       01107
#
#                                                      1  \
# county_name                     Sumter County, Alabama
# %_inschool_3+                                     4106
# %_preschool_3+                                     4.4
# %_kinderg_3+                                       5.9
# %_elementary_3+                                   26.9
# %_highschool_3+                                   18.8
# %_college_3+                                      44.1
# %_25+                                             8244
# %_below9th_25+                                     4.7
# %_9th-12th_25+                                    12.6
# %_hsgrad_25+                                      39.7
# %_somecollege_25+                                 17.7
# %_associates_25+                                   7.0
# %_bachelors_b25+                                  10.6
# %_gradschool_25+                                   7.6
# %_hsgrad_or+_25+                                  82.7
# %_bachelors_or+_25+                               18.2
# %_useinternet_total_households                    5073
# %_havecomp_total_households                       64.8
# %_broadband_total_households                      50.4
# state                                               01
# county                                             119
# county_code                                      01119
#
#                                                         2
# county_name                     Jefferson County, Alabama
# %_inschool_3+                                      165739
# %_preschool_3+                                        6.8
# %_kinderg_3+                                          5.7
# %_elementary_3+                                      39.9
# %_highschool_3+                                      20.5
# %_college_3+                                         27.1
# %_25+                                              447048
# %_below9th_25+                                        3.0
# %_9th-12th_25+                                        7.6
# %_hsgrad_25+                                         26.8
# %_somecollege_25+                                    22.6
# %_associates_25+                                      8.1
# %_bachelors_b25+                                     19.4
# %_gradschool_25+                                     12.5
# %_hsgrad_or+_25+                                     89.4
# %_bachelors_or+_25+                                  31.9
# %_useinternet_total_households                     261390
# %_havecomp_total_households                          84.4
# %_broadband_total_households                         73.0
# state                                                  01
# county                                                073
# county_code                                         01073

# %%
#change the Census datatypes from strings to integers and floats 
counties_df['county_code'] = counties_df['county_code'].astype(int)
counties_df['state'] = counties_df['state'].astype(int)
counties_df['county'] = counties_df['county'].astype(int)
counties_df.iloc[:,1:-3] = counties_df.iloc[:,1:-3].astype(float)
counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3142 entries, 0 to 3141
# Data columns (total 23 columns):
# county_name                       3142 non-null object
# %_inschool_3+                     3142 non-null float64
# %_preschool_3+                    3142 non-null float64
# %_kinderg_3+                      3142 non-null float64
# %_elementary_3+                   3142 non-null float64
# %_highschool_3+                   3142 non-null float64
# %_college_3+                      3142 non-null float64
# %_25+                             3142 non-null float64
# %_below9th_25+                    3142 non-null float64
# %_9th-12th_25+                    3142 non-null float64
# %_hsgrad_25+                      3142 non-null float64
# %_somecollege_25+                 3142 non-null float64
# %_associates_25+                  3142 non-null float64
# %_bachelors_b25+                  3142 non-null float64
# %_gradschool_25+                  3142 non-null float64
# %_hsgrad_or+_25+                  3142 non-null float64
# %_bachelors_or+_25+               3142 non-null float64
# %_useinternet_total_households    3142 non-null float64
# %_havecomp_total_households       3142 non-null float64
# %_broadband_total_households      3142 non-null float64
# state                             3142 non-null int64
# county                            3142 non-null int64
# county_code                       3142 non-null int64
# dtypes: float64(19), int64(3), object(1)
# memory usage: 589.1+ KB

# %%
#change the CDC datatypes too 
od_reliable['County Code'] = od_reliable['County Code'].astype(int)
od_reliable['Deaths'] = od_reliable['Deaths'].astype(int)
od_reliable['Population'] = od_reliable['Population'].astype(int)
od_reliable['Crude Rate'] = od_reliable['Crude Rate'].astype(float)

# %%
od_reliable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2016 entries, 0 to 3144
# Data columns (total 6 columns):
# County               2016 non-null object
# County Code          2016 non-null int64
# Deaths               2016 non-null int64
# Population           2016 non-null int64
# Crude Rate           2016 non-null float64
# % of Total Deaths    2016 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 110.2+ KB

# %%
od_reliable['% of Total Deaths'] = od_reliable['% of Total Deaths'].str.replace("%", "")
od_reliable['% of Total Deaths'] = od_reliable['% of Total Deaths'].astype(float)

# %%
od_df = od_reliable

# %%
od_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2016 entries, 0 to 3144
# Data columns (total 6 columns):
# County               2016 non-null object
# County Code          2016 non-null int64
# Deaths               2016 non-null int64
# Population           2016 non-null int64
# Crude Rate           2016 non-null float64
# % of Total Deaths    2016 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 110.2+ KB

# %%
#join the data
counties_data = od_df.merge(counties_df, how='inner', left_on='County Code', right_on='county_code')

# %%
counties_data.drop(['County Code', 'county_name'], axis=1, inplace=True)

# %%
counties_data
# Out:
#                       County  Deaths  Population  Crude Rate  \
# 0         Autauga County, AL      47      276908     16.9731
# 1         Baldwin County, AL     253     1020551     24.7905
# 2            Bibb County, AL      27      112912     23.9124
# 3          Blount County, AL      88      288981     30.4518
# 4         Calhoun County, AL     132      577611     22.8528
# 5        Chambers County, AL      34      169917     20.0098
# 6        Cherokee County, AL      40      129681     30.8449
# 7         Chilton County, AL      42      219833     19.1054
# 8          Coffee County, AL      39      256158     15.2250
# 9         Colbert County, AL      39      272133     14.3312
# 10      Covington County, AL      24      188185     12.7534
# 11        Cullman County, AL     147      409331     35.9123
# 12           Dale County, AL      44      247385     17.7860
# 13         Dallas County, AL      29      204061     14.2114
# 14         DeKalb County, AL     111      355725     31.2039
# 15         Elmore County, AL      57      406823     14.0110
# 16       Escambia County, AL      93      188680     49.2898
# 17         Etowah County, AL     160      515838     31.0175
# 18        Fayette County, AL      22       83556     26.3296
# 19       Franklin County, AL      40      157952     25.3241
# 20         Geneva County, AL      41      133251     30.7690
# 21        Houston County, AL     116      520436     22.2890
# 22        Jackson County, AL      41      262082     15.6440
# 23      Jefferson County, AL    1331     3299357     40.3412
# 24     Lauderdale County, AL      86      463345     18.5607
# 25       Lawrence County, AL      34      166472     20.4239
# 26            Lee County, AL     110      782776     14.0526
# 27      Limestone County, AL      43      458450      9.3794
# 28        Madison County, AL     339     1768293     19.1710
# 29       Marshall County, AL     137      474826     28.8527
# ...                      ...     ...         ...         ...
# 1985         Rusk County, WI      23       71130     32.3352
# 1986    St. Croix County, WI      80      436934     18.3094
# 1987         Sauk County, WI      79      318113     24.8339
# 1988       Sawyer County, WI      38       82113     46.2777
# 1989      Shawano County, WI      41      206523     19.8525
# 1990    Sheboygan County, WI     180      576552     31.2201
# 1991  Trempealeau County, WI      22      147746     14.8904
# 1992       Vernon County, WI      26      152770     17.0190
# 1993        Vilas County, WI      42      107271     39.1532
# 1994     Walworth County, WI     144      515317     27.9440
# 1995     Washburn County, WI      26       78338     33.1895
# 1996   Washington County, WI     163      669061     24.3625
# 1997     Waukesha County, WI     434     1984494     21.8696
# 1998      Waupaca County, WI      71      259054     27.4074
# 1999     Waushara County, WI      24      121071     19.8231
# 2000    Winnebago County, WI     231      848898     27.2117
# 2001         Wood County, WI      93      367235     25.3244
# 2002       Albany County, WY      50      189777     26.3467
# 2003     Big Horn County, WY      23       59857     38.4249
# 2004     Campbell County, WY      81      240761     33.6433
# 2005       Carbon County, WY      42       78082     53.7896
# 2006     Converse County, WY      21       70646     29.7257
# 2007      Fremont County, WY     154      202061     76.2146
# 2008      Laramie County, WY     175      485782     36.0244
# 2009      Lincoln County, WY      29       94028     30.8419
# 2010      Natrona County, WY     197      405361     48.5987
# 2011         Park County, WY      43      146365     29.3786
# 2012     Sheridan County, WY      54      150275     35.9341
# 2013   Sweetwater County, WY      99      222572     44.4800
# 2014        Uinta County, WY      46      104060     44.2053
#
#       % of Total Deaths  %_inschool_3+  %_preschool_3+  %_kinderg_3+  \
# 0                0.0103        13438.0             3.9           7.1
# 1                0.0554        44265.0             6.2           4.9
# 2                0.0059         4626.0             3.0           4.9
# 3                0.0193        12428.0             3.9           4.4
# 4                0.0289        27798.0             6.2           5.3
# 5                0.0074         7081.0             5.6           3.3
# 6                0.0088         5109.0             3.8           4.9
# 7                0.0092         9659.0             4.9           7.2
# 8                0.0085        11864.0             4.5           6.3
# 9                0.0085        11445.0             3.9           4.5
# 10               0.0053         7867.0             6.7           6.9
# 11               0.0322        17023.0             6.2           4.6
# 12               0.0096        11997.0             6.1           4.6
# 13               0.0064        10463.0             5.0           6.4
# 14               0.0243        16508.0             4.0           6.1
# 15               0.0125        18985.0             7.2           4.2
# 16               0.0204         7875.0             4.5           7.1
# 17               0.0351        23061.0             4.3           5.7
# 18               0.0048         3604.0             5.0           5.9
# 19               0.0088         7426.0             3.3           6.8
# 20               0.0090         5667.0             3.2           5.5
# 21               0.0254        24833.0             4.9           5.3
# 22               0.0090        10509.0             4.8           5.7
# 23               0.2916       165739.0             6.8           5.7
# 24               0.0188        22423.0             5.3           4.9
# 25               0.0074         7198.0             3.4           6.4
# 26               0.0241        54453.0             3.7           3.4
# 27               0.0094        21605.0             4.3           4.6
# 28               0.0743        93979.0             5.6           4.5
# 29               0.0300        22374.0             6.0           4.5
# ...                 ...            ...             ...           ...
# 1985             0.0050         2690.0             6.4           3.8
# 1986             0.0175        22556.0             5.9           6.0
# 1987             0.0173        14178.0             8.0           5.6
# 1988             0.0083         3104.0             5.2           5.9
# 1989             0.0090         8769.0             6.5           5.7
# 1990             0.0394        27250.0             4.8           6.4
# 1991             0.0048         6573.0             6.3           6.5
# 1992             0.0057         6440.0             5.5           6.5
# 1993             0.0092         3495.0             6.7           5.8
# 1994             0.0315        28324.0             4.7           5.0
# 1995             0.0057         2788.0             6.2           5.2
# 1996             0.0357        31410.0             5.8           5.5
# 1997             0.0951        98092.0             5.9           6.0
# 1998             0.0156        10772.0             4.4           7.8
# 1999             0.0053         4309.0             4.8           6.5
# 2000             0.0506        42995.0             5.4           4.7
# 2001             0.0204        15620.0             6.8           5.5
# 2002             0.0110        16268.0             3.3           2.4
# 2003             0.0050         2933.0             6.3           4.8
# 2004             0.0177        12131.0             5.1           6.2
# 2005             0.0092         3646.0            10.4           6.5
# 2006             0.0046         3259.0             9.4           6.2
# 2007             0.0337        10169.0             9.1           5.7
# 2008             0.0383        23925.0             5.5           5.4
# 2009             0.0064         4972.0             7.2           7.0
# 2010             0.0432        19616.0             6.2           6.5
# 2011             0.0094         6337.0             4.5           6.4
# 2012             0.0118         6683.0             4.8           5.0
# 2013             0.0217        12116.0             5.9           4.4
# 2014             0.0101         5557.0             6.8           6.3
#
#       %_elementary_3+  %_highschool_3+  ...  %_bachelors_b25+  \
# 0                46.3             24.8  ...              14.5
# 1                46.5             24.3  ...              20.4
# 2                44.0             28.7  ...               8.1
# 3                49.3             25.9  ...               8.7
# 4                41.4             20.6  ...              10.2
# 5                48.2             21.5  ...               9.0
# 6                47.8             27.6  ...               6.6
# 7                48.6             24.0  ...               9.5
# 8                45.0             25.9  ...              14.7
# 9                46.8             24.6  ...              11.5
# 10               47.3             21.6  ...              10.4
# 11               47.4             24.1  ...               9.5
# 12               44.0             21.6  ...              11.1
# 13               42.5             24.9  ...               8.1
# 14               49.4             23.6  ...               7.6
# 15               44.2             24.1  ...              14.4
# 16               47.5             25.5  ...               7.6
# 17               44.9             23.7  ...              10.4
# 18               45.6             24.7  ...              10.1
# 19               49.2             23.3  ...               8.3
# 20               48.5             27.5  ...               7.5
# 21               46.3             22.7  ...              13.2
# 22               48.9             26.6  ...               8.6
# 23               39.9             20.5  ...              19.4
# 24               37.4             18.9  ...              13.8
# 25               47.6             23.8  ...               7.2
# 26               28.1             13.2  ...              19.8
# 27               45.3             25.2  ...              16.5
# 28               37.4             19.7  ...              25.2
# 29               49.3             22.8  ...              11.6
# ...               ...              ...  ...               ...
# 1985             53.5             25.1  ...              10.0
# 1986             46.0             23.1  ...              24.0
# 1987             46.0             23.0  ...              15.7
# 1988             49.9             24.7  ...              14.2
# 1989             46.4             24.3  ...              10.1
# 1990             43.9             24.0  ...              16.7
# 1991             48.6             23.6  ...              13.8
# 1992             53.2             23.3  ...              14.1
# 1993             46.2             23.1  ...              17.8
# 1994             35.8             19.5  ...              18.1
# 1995             50.7             24.9  ...              15.0
# 1996             44.6             24.4  ...              21.7
# 1997             40.3             23.5  ...              28.3
# 1998             46.3             25.5  ...              13.5
# 1999             45.1             27.0  ...               9.7
# 2000             36.5             18.6  ...              19.5
# 2001             45.4             24.2  ...              13.4
# 2002             16.3              7.4  ...              28.3
# 2003             49.1             24.8  ...              14.0
# 2004             52.8             19.6  ...              14.0
# 2005             44.7             23.0  ...              15.1
# 2006             48.7             23.0  ...              12.3
# 2007             45.1             21.1  ...              15.5
# 2008             43.4             19.1  ...              17.9
# 2009             49.4             22.2  ...              14.7
# 2010             42.8             20.0  ...              14.9
# 2011             41.7             21.4  ...              19.2
# 2012             44.1             22.8  ...              18.3
# 2013             45.7             21.5  ...              15.3
# 2014             53.9             21.6  ...              11.9
#
#       %_gradschool_25+  %_hsgrad_or+_25+  %_bachelors_or+_25+  \
# 0                 10.5              87.7                 25.0
# 1                 10.3              90.2                 30.7
# 2                  5.1              82.1                 13.2
# 3                  4.4              79.8                 13.1
# 4                  7.6              83.2                 17.9
# 5                  4.3              80.9                 13.3
# 6                  5.9              79.5                 12.5
# 7                  5.6              81.8                 15.1
# 8                  8.0              85.4                 22.7
# 9                  7.3              83.9                 18.8
# 10                 5.1              82.0                 15.5
# 11                 5.4              82.1                 14.9
# 12                 5.7              86.0                 16.8
# 13                 6.1              81.3                 14.2
# 14                 5.4              73.6                 13.0
# 15                 8.4              86.4                 22.8
# 16                 4.6              81.0                 12.1
# 17                 6.5              83.1                 16.9
# 18                 4.6              79.6                 14.6
# 19                 5.1              76.4                 13.4
# 20                 3.6              79.0                 11.1
# 21                 7.7              85.3                 20.9
# 22                 4.8              81.4                 13.4
# 23                12.5              89.4                 31.9
# 24                 8.7              85.9                 22.5
# 25                 3.0              78.0                 10.2
# 26                15.1              89.9                 34.9
# 27                 8.1              83.7                 24.6
# 28                15.4              90.8                 40.6
# 29                 6.1              80.0                 17.7
# ...                ...               ...                  ...
# 1985               4.8              87.0                 14.8
# 1986              10.0              96.1                 34.0
# 1987               7.7              91.0                 23.4
# 1988               7.9              91.4                 22.0
# 1989               5.7              91.0                 15.8
# 1990               7.1              92.4                 23.8
# 1991               5.8              89.6                 19.7
# 1992               7.5              88.7                 21.6
# 1993               9.3              92.6                 27.1
# 1994              10.4              91.0                 28.5
# 1995               7.0              92.1                 22.0
# 1996               8.0              94.4                 29.7
# 1997              14.7              96.0                 42.9
# 1998               5.0              91.2                 18.5
# 1999               5.5              86.2                 15.2
# 2000               7.8              92.4                 27.3
# 2001               7.7              92.6                 21.1
# 2002              21.5              96.2                 49.8
# 2003               5.2              90.5                 19.2
# 2004               4.5              91.3                 18.5
# 2005               5.8              90.9                 20.9
# 2006               5.8              90.3                 18.2
# 2007               7.7              91.1                 23.3
# 2008              10.8              93.2                 28.7
# 2009               5.8              92.9                 20.5
# 2010               7.9              92.2                 22.8
# 2011              13.1              95.1                 32.2
# 2012              13.0              95.3                 31.3
# 2013               6.9              91.3                 22.2
# 2014               5.5              91.8                 17.4
#
#       %_useinternet_total_households  %_havecomp_total_households  \
# 0                            21054.0                         86.2
# 1                            76133.0                         86.9
# 2                             6916.0                         74.8
# 3                            20690.0                         78.2
# 4                            45099.0                         82.9
# 5                            13694.0                         72.7
# 6                            10795.0                         79.4
# 7                            16768.0                         73.8
# 8                            19620.0                         84.1
# 9                            21983.0                         80.3
# 10                           15285.0                         74.1
# 11                           31097.0                         78.9
# 12                           18825.0                         81.3
# 13                           16487.0                         69.2
# 14                           25482.0                         75.3
# 15                           29115.0                         86.7
# 16                           13226.0                         63.4
# 17                           39061.0                         80.7
# 18                            6955.0                         73.8
# 19                           11533.0                         74.2
# 20                           10693.0                         79.0
# 21                           39560.0                         78.2
# 22                           20368.0                         75.0
# 23                          261390.0                         84.4
# 24                           38634.0                         78.8
# 25                           13056.0                         74.6
# 26                           59001.0                         88.3
# 27                           32386.0                         82.8
# 28                          142253.0                         89.5
# 29                           34588.0                         79.8
# ...                              ...                          ...
# 1985                          6294.0                         78.9
# 1986                         33389.0                         91.5
# 1987                         25678.0                         84.4
# 1988                          7573.0                         81.8
# 1989                         17024.0                         80.3
# 1990                         47532.0                         86.6
# 1991                         11892.0                         79.9
# 1992                         12095.0                         76.2
# 1993                         10758.0                         81.7
# 1994                         40246.0                         89.5
# 1995                          7142.0                         82.7
# 1996                         53756.0                         88.9
# 1997                        156996.0                         92.0
# 1998                         21793.0                         83.1
# 1999                          9851.0                         80.2
# 2000                         69759.0                         87.1
# 2001                         32223.0                         82.0
# 2002                         16009.0                         94.5
# 2003                          4481.0                         86.7
# 2004                         17588.0                         93.4
# 2005                          6205.0                         83.4
# 2006                          5630.0                         91.0
# 2007                         15167.0                         86.1
# 2008                         38447.0                         91.5
# 2009                          7063.0                         91.8
# 2010                         32984.0                         88.9
# 2011                         11811.0                         90.5
# 2012                         13130.0                         85.9
# 2013                         16269.0                         92.1
# 2014                          7705.0                         91.2
#
#       %_broadband_total_households  state  county  county_code
# 0                             76.6      1       1         1001
# 1                             74.5      1       3         1003
# 2                             62.0      1       7         1007
# 3                             65.8      1       9         1009
# 4                             71.0      1      15         1015
# 5                             62.8      1      17         1017
# 6                             67.5      1      19         1019
# 7                             56.6      1      21         1021
# 8                             75.3      1      31         1031
# 9                             65.9      1      33         1033
# 10                            64.7      1      39         1039
# 11                            65.2      1      43         1043
# 12                            69.8      1      45         1045
# 13                            57.7      1      47         1047
# 14                            61.0      1      49         1049
# 15                            78.2      1      51         1051
# 16                            54.9      1      53         1053
# 17                            68.4      1      55         1055
# 18                            64.1      1      57         1057
# 19                            60.3      1      59         1059
# 20                            64.3      1      61         1061
# 21                            67.6      1      69         1069
# 22                            62.7      1      71         1071
# 23                            73.0      1      73         1073
# 24                            65.4      1      77         1077
# 25                            55.7      1      79         1079
# 26                            78.2      1      81         1081
# 27                            72.5      1      83         1083
# 28                            81.3      1      89         1089
# 29                            70.2      1      95         1095
# ...                            ...    ...     ...          ...
# 1985                          66.0     55     107        55107
# 1986                          83.3     55     109        55109
# 1987                          76.3     55     111        55111
# 1988                          72.1     55     113        55113
# 1989                          72.8     55     115        55115
# 1990                          79.7     55     117        55117
# 1991                          71.8     55     121        55121
# 1992                          66.8     55     123        55123
# 1993                          68.8     55     125        55125
# 1994                          79.5     55     127        55127
# 1995                          71.9     55     129        55129
# 1996                          83.7     55     131        55131
# 1997                          87.5     55     133        55133
# 1998                          73.5     55     135        55135
# 1999                          68.9     55     137        55137
# 2000                          78.8     55     139        55139
# 2001                          75.8     55     141        55141
# 2002                          81.0     56       1        56001
# 2003                          72.0     56       3        56003
# 2004                          86.4     56       5        56005
# 2005                          72.5     56       7        56007
# 2006                          76.2     56       9        56009
# 2007                          71.9     56      13        56013
# 2008                          82.4     56      21        56021
# 2009                          76.2     56      23        56023
# 2010                          78.5     56      25        56025
# 2011                          80.4     56      29        56029
# 2012                          80.9     56      33        56033
# 2013                          82.2     56      37        56037
# 2014                          83.8     56      41        56041
#
# [2015 rows x 27 columns]

# %% [markdown]
# ## Investigate the data

# %%
import matplotlib.pyplot as plt
plt.scatter(counties_data['state'], counties_data['Crude Rate'])
plt.title('Crude Death Rate per State');

# %%
#we likely won't use the % of total deaths in the county, but it was interesting to keep in until this point.
#there is an error in los angeles county, so we ignore that maximum value for this graph 
counties_real_percents = counties_data[counties_data['% of Total Deaths']<=1]

# %%
plt.hist(counties_real_percents['% of Total Deaths'], bins=10);

# %%
plt.hist(counties_data['Crude Rate'], bins=100);

# %%
#find the 10% of counties with the worst overdose rates 
len(counties_data[counties_data['Crude Rate']>=48])/len(counties_data)
# Out:
# 0.0977667493796526

# %%
import numpy as np
counties_data.describe()
# Out:
#              Deaths    Population   Crude Rate  % of Total Deaths  \
# count   2015.000000  2.015000e+03  2015.000000        2015.000000
# mean     221.504218  7.697052e+05    31.182003           0.048531
# std      519.332693  2.003106e+06    13.944111           0.113782
# min       20.000000  2.092900e+04     7.899600           0.004400
# 25%       36.000000  1.354240e+05    21.744650           0.007900
# 50%       70.000000  2.421540e+05    28.348700           0.015300
# 75%      180.500000  6.167530e+05    37.341300           0.039550
# max    10349.000000  5.060549e+07   156.161100           2.267400
#
#        %_inschool_3+  %_preschool_3+  %_kinderg_3+  %_elementary_3+  \
# count   2.015000e+03     2015.000000   2015.000000      2015.000000
# mean    3.934429e+04        5.909628      5.365856        43.201241
# std     1.059416e+05        1.509989      1.347735         6.256521
# min     1.199000e+03        1.400000      1.100000        13.200000
# 25%     5.998000e+03        4.900000      4.600000        40.700000
# 50%     1.144500e+04        5.900000      5.300000        44.000000
# 75%     3.134150e+04        6.800000      6.100000        47.100000
# max     2.704769e+06       13.900000     11.800000        67.800000
#
#        %_highschool_3+  %_college_3+  ...  %_bachelors_b25+  %_gradschool_25+  \
# count      2015.000000   2015.000000  ...       2015.000000       2015.000000
# mean         22.344268     23.178759  ...         14.497519          8.366352
# std           3.620372     10.096346  ...          5.816358          4.557504
# min           5.900000      3.700000  ...          2.800000          1.900000
# 25%          20.800000     16.900000  ...         10.100000          5.300000
# 50%          22.700000     20.700000  ...         13.200000          7.000000
# 75%          24.600000     26.400000  ...         17.900000         10.300000
# max          37.900000     76.400000  ...         39.000000         40.300000
#
#        %_hsgrad_or+_25+  %_bachelors_or+_25+  %_useinternet_total_households  \
# count       2015.000000          2015.000000                    2.015000e+03
# mean          86.622878            22.862829                    5.689684e+04
# std            5.749122             9.954506                    1.397341e+05
# min           58.200000             4.900000                    1.114000e+03
# 25%           83.400000            15.500000                    1.041150e+04
# 50%           87.700000            20.200000                    1.853700e+04
# 75%           90.800000            28.150000                    4.621400e+04
# max           98.000000            74.100000                    3.295198e+06
#
#        %_havecomp_total_households  %_broadband_total_households        state  \
# count                  2015.000000                   2015.000000  2015.000000
# mean                     83.134839                     72.260943    30.905211
# std                       6.709357                      8.962677    15.327295
# min                      49.800000                     38.600000     1.000000
# 25%                      79.400000                     66.800000    18.000000
# 50%                      83.800000                     72.900000    30.000000
# 75%                      87.850000                     78.600000    45.000000
# max                      97.800000                     94.600000    56.000000
#
#             county   county_code
# count  2015.000000   2015.000000
# mean     97.572208  31002.783127
# std     106.438226  15344.335467
# min       1.000000   1001.000000
# 25%      31.000000  18132.000000
# 50%      73.000000  30111.000000
# 75%     125.000000  45052.000000
# max     840.000000  56041.000000
#
# [8 rows x 26 columns]

# %%
#label our data as high risk 0 or not high risk 1  
counties_data.loc[(counties_data['Crude Rate'] < 48), 'high_risk'] = 0
counties_data.loc[(counties_data['Crude Rate'] >= 48), 'high_risk'] = 1

# %%
counties_data.head().T
# Out:
#                                                  0                   1  \
# County                          Autauga County, AL  Baldwin County, AL
# Deaths                                          47                 253
# Population                                  276908             1020551
# Crude Rate                                 16.9731             24.7905
# % of Total Deaths                           0.0103              0.0554
# %_inschool_3+                                13438               44265
# %_preschool_3+                                 3.9                 6.2
# %_kinderg_3+                                   7.1                 4.9
# %_elementary_3+                               46.3                46.5
# %_highschool_3+                               24.8                24.3
# %_college_3+                                  17.9                18.1
# %_25+                                        36757              143022
# %_below9th_25+                                   3                 2.6
# %_9th-12th_25+                                 9.3                 7.2
# %_hsgrad_25+                                  33.6                27.8
# %_somecollege_25+                             21.5                  22
# %_associates_25+                               7.6                 9.6
# %_bachelors_b25+                              14.5                20.4
# %_gradschool_25+                              10.5                10.3
# %_hsgrad_or+_25+                              87.7                90.2
# %_bachelors_or+_25+                             25                30.7
# %_useinternet_total_households               21054               76133
# %_havecomp_total_households                   86.2                86.9
# %_broadband_total_households                  76.6                74.5
# state                                            1                   1
# county                                           1                   3
# county_code                                   1001                1003
# high_risk                                        0                   0
#
#                                               2                  3  \
# County                          Bibb County, AL  Blount County, AL
# Deaths                                       27                 88
# Population                               112912             288981
# Crude Rate                              23.9124            30.4518
# % of Total Deaths                        0.0059             0.0193
# %_inschool_3+                              4626              12428
# %_preschool_3+                                3                3.9
# %_kinderg_3+                                4.9                4.4
# %_elementary_3+                              44               49.3
# %_highschool_3+                            28.7               25.9
# %_college_3+                               19.3               16.5
# %_25+                                     15859              39475
# %_below9th_25+                              5.6                7.3
# %_9th-12th_25+                             12.3               12.9
# %_hsgrad_25+                               43.9               32.3
# %_somecollege_25+                          19.8               21.9
# %_associates_25+                            5.2               12.5
# %_bachelors_b25+                            8.1                8.7
# %_gradschool_25+                            5.1                4.4
# %_hsgrad_or+_25+                           82.1               79.8
# %_bachelors_or+_25+                        13.2               13.1
# %_useinternet_total_households             6916              20690
# %_havecomp_total_households                74.8               78.2
# %_broadband_total_households                 62               65.8
# state                                         1                  1
# county                                        7                  9
# county_code                                1007               1009
# high_risk                                     0                  0
#
#                                                  4
# County                          Calhoun County, AL
# Deaths                                         132
# Population                                  577611
# Crude Rate                                 22.8528
# % of Total Deaths                           0.0289
# %_inschool_3+                                27798
# %_preschool_3+                                 6.2
# %_kinderg_3+                                   5.3
# %_elementary_3+                               41.4
# %_highschool_3+                               20.6
# %_college_3+                                  26.5
# %_25+                                        78975
# %_below9th_25+                                   5
# %_9th-12th_25+                                11.8
# %_hsgrad_25+                                  32.2
# %_somecollege_25+                             25.8
# %_associates_25+                               7.4
# %_bachelors_b25+                              10.2
# %_gradschool_25+                               7.6
# %_hsgrad_or+_25+                              83.2
# %_bachelors_or+_25+                           17.9
# %_useinternet_total_households               45099
# %_havecomp_total_households                   82.9
# %_broadband_total_households                    71
# state                                            1
# county                                          15
# county_code                                   1015
# high_risk                                        0

# %% [markdown]
# # Modeling
# ## Split our data into training and test sets

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

# %%
X = counties_data.drop(columns=['high_risk','county_code','state','county',
                                'County','Deaths','Population','Crude Rate','% of Total Deaths' 
                                ])
y = counties_data['high_risk']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2)

# %% [markdown]
# ## Creating a Logistic Regression

# %%
#import necessary libraries 
from sklearn.metrics import accuracy_score,f1_score,roc_auc_score, log_loss
from sklearn.decomposition import PCA
from sklearn_pandas.pipeline import Pipeline as Pipe
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
#create a pipeline that scales and creates a logistic regression object 
pipe = Pipe(steps=[
    ('scaler' , StandardScaler()),
    ('logreg' , LogisticRegression(penalty= 'l1', fit_intercept = True, solver='liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logreg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l1', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
y_hat_train_probs = pipe.predict_proba(X_train)
y_hat_test_probs = pipe.predict_proba(X_test)
y_hat_train_probs #our predicted probabilities for 0,1 respectively
# Out:
# array([[0.90785535, 0.09214465],
#        [0.8540226 , 0.1459774 ],
#        [0.71755956, 0.28244044],
#        ...,
#        [0.95783214, 0.04216786],
#        [0.97436209, 0.02563791],
#        [0.96369215, 0.03630785]])

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, recall_score, f1_score
y_hat_test_1_probs = pipe.predict_proba(X_test)[:,1]#only take probability for 1
fpr, tpr, thresholds = roc_curve(y_test, y_hat_test_1_probs)
y_hat_train_1_probs = pipe.predict_proba(X_train)[:,1]
train_fpr, train_tpr, thresholds = roc_curve(y_train, y_hat_train_1_probs)
print(f"Train ROC/AUC Score: {roc_auc_score(y_train, y_hat_train_1_probs)}") 
print(f"Test ROC/AUC Score: {roc_auc_score(y_test, y_hat_test_1_probs)}")
# Out:
# Train ROC/AUC Score: 0.7620566460055097
# Test ROC/AUC Score: 0.7510707428740216

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#set seaborn styling
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#set figure size
plt.figure(figsize=(10,8))
lw = 3 #linewidth
plt.plot(fpr, tpr, color='purple',
         lw=lw, label='ROC curve (Test Data)') #plot the fpr and tpr 
plt.plot([0, 1], [0, 1], color='gray', lw=lw, linestyle='--') #plot the 50% rating 
plt.xlim([-0.05, 1.0]) #set plot domain
plt.ylim([-0.05, 1.05])#set plot range 
plt.yticks([i/10.0 for i in range(11)]) 
plt.xticks([i/10.0 for i in range(11)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC Curve for Test Data")
plt.legend(loc="upper left")
print('AUC: {}'.format(roc_auc_score(y_test, y_hat_test_1_probs)))
plt.show()
# Out:
# AUC: 0.7510707428740216

# %%
print(f"ROC/AUC score:{roc_auc_score(y_test, y_hat_test_1_probs)}")
print(f"Log Loss:{log_loss(y_test, y_hat_test_1_probs)}")
print(f"Accuracy score:{accuracy_score(y_test, y_hat_test_1_probs>=.5)}")
print(f"Precision score:{precision_score(y_test, y_hat_test_1_probs>=.5)}")
print(f"Recall score:{recall_score(y_test, y_hat_test_1_probs>=.5)}")
print(f"f1 score:{f1_score(y_test, y_hat_test_1_probs>=.5)}")
#perform cross-validation
pipe_cv_score = cross_val_score(pipe, X_test, y_test, cv=5, scoring='roc_auc')
mean_pipe_cv_score = pipe_cv_score.mean()
print("Mean Cross Validation ROC/AUC Score: {:.4}%".format(mean_pipe_cv_score * 100))
# Out:
# ROC/AUC score:0.7510707428740216
# Log Loss:0.2748655467901126
# Accuracy score:0.9057071960297767
# Precision score:0.4
# Recall score:0.05405405405405406
# f1 score:0.09523809523809523
# Mean Cross Validation ROC/AUC Score: 71.79%

# %% [markdown]
# For our business case, we want our recall to be quite high (alerting counties when there is even a small chance they could be at high risk), and right now we are only capturing 5% of the actual high-risk counties!
#
# We can do better than that.
#
# ## Engineering the state feature with one hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
counties_data['state'].value_counts()
# Out:
# 48    123
# 13     92
# 21     90
# 37     89
# 51     88
# 39     84
# 47     80
# 18     77
# 26     71
# 17     64
# 55     64
# 42     63
# 29     63
# 36     60
# 12     60
# 40     56
# 6      55
# 27     47
# 1      42
# 22     41
# 54     41
# 28     41
# 5      39
# 45     39
# 53     36
# 8      35
# 41     30
# 20     29
# 19     28
# 35     25
# 24     24
# 16     21
# 34     21
# 30     20
# 49     18
# 23     16
# 4      14
# 31     14
# 56     13
# 46     13
# 38     13
# 25     13
# 50     12
# 32     10
# 33     10
# 2      10
# 9       8
# 44      5
# 15      4
# 10      3
# 11      1
# Name: state, dtype: int64

# %%
state_cols = counties_data["state"].values.reshape(-1, 1)
state_cols[:5]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [1]])

# %%
encoder = OneHotEncoder().fit(state_cols)
# Out:
# /Users/tjjj/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
encoder.get_feature_names(["state_cols"])
# Out:
# array(['state_cols_1.0', 'state_cols_2.0', 'state_cols_4.0',
#        'state_cols_5.0', 'state_cols_6.0', 'state_cols_8.0',
#        'state_cols_9.0', 'state_cols_10.0', 'state_cols_11.0',
#        'state_cols_12.0', 'state_cols_13.0', 'state_cols_15.0',
#        'state_cols_16.0', 'state_cols_17.0', 'state_cols_18.0',
#        'state_cols_19.0', 'state_cols_20.0', 'state_cols_21.0',
#        'state_cols_22.0', 'state_cols_23.0', 'state_cols_24.0',
#        'state_cols_25.0', 'state_cols_26.0', 'state_cols_27.0',
#        'state_cols_28.0', 'state_cols_29.0', 'state_cols_30.0',
#        'state_cols_31.0', 'state_cols_32.0', 'state_cols_33.0',
#        'state_cols_34.0', 'state_cols_35.0', 'state_cols_36.0',
#        'state_cols_37.0', 'state_cols_38.0', 'state_cols_39.0',
#        'state_cols_40.0', 'state_cols_41.0', 'state_cols_42.0',
#        'state_cols_44.0', 'state_cols_45.0', 'state_cols_46.0',
#        'state_cols_47.0', 'state_cols_48.0', 'state_cols_49.0',
#        'state_cols_50.0', 'state_cols_51.0', 'state_cols_53.0',
#        'state_cols_54.0', 'state_cols_55.0', 'state_cols_56.0'],
#       dtype=object)

# %%
ohe = pd.DataFrame(encoder.transform(state_cols).toarray(),
                   columns=encoder.get_feature_names(["state_cols"]))

# %%
counties_encoded = pd.concat([counties_data.drop(['state'], axis=1), ohe], axis=1)

# %%
counties_encoded.drop(['state_cols_56.0'], axis=1, inplace=True)
counties_encoded.head().T
# Out:
#                                                  0                   1  \
# County                          Autauga County, AL  Baldwin County, AL
# Deaths                                          47                 253
# Population                                  276908             1020551
# Crude Rate                                 16.9731             24.7905
# % of Total Deaths                           0.0103              0.0554
# %_inschool_3+                                13438               44265
# %_preschool_3+                                 3.9                 6.2
# %_kinderg_3+                                   7.1                 4.9
# %_elementary_3+                               46.3                46.5
# %_highschool_3+                               24.8                24.3
# %_college_3+                                  17.9                18.1
# %_25+                                        36757              143022
# %_below9th_25+                                   3                 2.6
# %_9th-12th_25+                                 9.3                 7.2
# %_hsgrad_25+                                  33.6                27.8
# %_somecollege_25+                             21.5                  22
# %_associates_25+                               7.6                 9.6
# %_bachelors_b25+                              14.5                20.4
# %_gradschool_25+                              10.5                10.3
# %_hsgrad_or+_25+                              87.7                90.2
# %_bachelors_or+_25+                             25                30.7
# %_useinternet_total_households               21054               76133
# %_havecomp_total_households                   86.2                86.9
# %_broadband_total_households                  76.6                74.5
# county                                           1                   3
# county_code                                   1001                1003
# high_risk                                        0                   0
# state_cols_1.0                                   1                   1
# state_cols_2.0                                   0                   0
# state_cols_4.0                                   0                   0
# ...                                            ...                 ...
# state_cols_24.0                                  0                   0
# state_cols_25.0                                  0                   0
# state_cols_26.0                                  0                   0
# state_cols_27.0                                  0                   0
# state_cols_28.0                                  0                   0
# state_cols_29.0                                  0                   0
# state_cols_30.0                                  0                   0
# state_cols_31.0                                  0                   0
# state_cols_32.0                                  0                   0
# state_cols_33.0                                  0                   0
# state_cols_34.0                                  0                   0
# state_cols_35.0                                  0                   0
# state_cols_36.0                                  0                   0
# state_cols_37.0                                  0                   0
# state_cols_38.0                                  0                   0
# state_cols_39.0                                  0                   0
# state_cols_40.0                                  0                   0
# state_cols_41.0                                  0                   0
# state_cols_42.0                                  0                   0
# state_cols_44.0                                  0                   0
# state_cols_45.0                                  0                   0
# state_cols_46.0                                  0                   0
# state_cols_47.0                                  0                   0
# state_cols_48.0                                  0                   0
# state_cols_49.0                                  0                   0
# state_cols_50.0                                  0                   0
# state_cols_51.0                                  0                   0
# state_cols_53.0                                  0                   0
# state_cols_54.0                                  0                   0
# state_cols_55.0                                  0                   0
#
#                                               2                  3  \
# County                          Bibb County, AL  Blount County, AL
# Deaths                                       27                 88
# Population                               112912             288981
# Crude Rate                              23.9124            30.4518
# % of Total Deaths                        0.0059             0.0193
# %_inschool_3+                              4626              12428
# %_preschool_3+                                3                3.9
# %_kinderg_3+                                4.9                4.4
# %_elementary_3+                              44               49.3
# %_highschool_3+                            28.7               25.9
# %_college_3+                               19.3               16.5
# %_25+                                     15859              39475
# %_below9th_25+                              5.6                7.3
# %_9th-12th_25+                             12.3               12.9
# %_hsgrad_25+                               43.9               32.3
# %_somecollege_25+                          19.8               21.9
# %_associates_25+                            5.2               12.5
# %_bachelors_b25+                            8.1                8.7
# %_gradschool_25+                            5.1                4.4
# %_hsgrad_or+_25+                           82.1               79.8
# %_bachelors_or+_25+                        13.2               13.1
# %_useinternet_total_households             6916              20690
# %_havecomp_total_households                74.8               78.2
# %_broadband_total_households                 62               65.8
# county                                        7                  9
# county_code                                1007               1009
# high_risk                                     0                  0
# state_cols_1.0                                1                  1
# state_cols_2.0                                0                  0
# state_cols_4.0                                0                  0
# ...                                         ...                ...
# state_cols_24.0                               0                  0
# state_cols_25.0                               0                  0
# state_cols_26.0                               0                  0
# state_cols_27.0                               0                  0
# state_cols_28.0                               0                  0
# state_cols_29.0                               0                  0
# state_cols_30.0                               0                  0
# state_cols_31.0                               0                  0
# state_cols_32.0                               0                  0
# state_cols_33.0                               0                  0
# state_cols_34.0                               0                  0
# state_cols_35.0                               0                  0
# state_cols_36.0                               0                  0
# state_cols_37.0                               0                  0
# state_cols_38.0                               0                  0
# state_cols_39.0                               0                  0
# state_cols_40.0                               0                  0
# state_cols_41.0                               0                  0
# state_cols_42.0                               0                  0
# state_cols_44.0                               0                  0
# state_cols_45.0                               0                  0
# state_cols_46.0                               0                  0
# state_cols_47.0                               0                  0
# state_cols_48.0                               0                  0
# state_cols_49.0                               0                  0
# state_cols_50.0                               0                  0
# state_cols_51.0                               0                  0
# state_cols_53.0                               0                  0
# state_cols_54.0                               0                  0
# state_cols_55.0                               0                  0
#
#                                                  4
# County                          Calhoun County, AL
# Deaths                                         132
# Population                                  577611
# Crude Rate                                 22.8528
# % of Total Deaths                           0.0289
# %_inschool_3+                                27798
# %_preschool_3+                                 6.2
# %_kinderg_3+                                   5.3
# %_elementary_3+                               41.4
# %_highschool_3+                               20.6
# %_college_3+                                  26.5
# %_25+                                        78975
# %_below9th_25+                                   5
# %_9th-12th_25+                                11.8
# %_hsgrad_25+                                  32.2
# %_somecollege_25+                             25.8
# %_associates_25+                               7.4
# %_bachelors_b25+                              10.2
# %_gradschool_25+                               7.6
# %_hsgrad_or+_25+                              83.2
# %_bachelors_or+_25+                           17.9
# %_useinternet_total_households               45099
# %_havecomp_total_households                   82.9
# %_broadband_total_households                    71
# county                                          15
# county_code                                   1015
# high_risk                                        0
# state_cols_1.0                                   1
# state_cols_2.0                                   0
# state_cols_4.0                                   0
# ...                                            ...
# state_cols_24.0                                  0
# state_cols_25.0                                  0
# state_cols_26.0                                  0
# state_cols_27.0                                  0
# state_cols_28.0                                  0
# state_cols_29.0                                  0
# state_cols_30.0                                  0
# state_cols_31.0                                  0
# state_cols_32.0                                  0
# state_cols_33.0                                  0
# state_cols_34.0                                  0
# state_cols_35.0                                  0
# state_cols_36.0                                  0
# state_cols_37.0                                  0
# state_cols_38.0                                  0
# state_cols_39.0                                  0
# state_cols_40.0                                  0
# state_cols_41.0                                  0
# state_cols_42.0                                  0
# state_cols_44.0                                  0
# state_cols_45.0                                  0
# state_cols_46.0                                  0
# state_cols_47.0                                  0
# state_cols_48.0                                  0
# state_cols_49.0                                  0
# state_cols_50.0                                  0
# state_cols_51.0                                  0
# state_cols_53.0                                  0
# state_cols_54.0                                  0
# state_cols_55.0                                  0
#
# [77 rows x 5 columns]

# %% [markdown]
# ## Split our encoded data

# %%
Xe = counties_encoded.drop(columns=['high_risk','county_code','county',
                                'County','Deaths','Population','Crude Rate','% of Total Deaths' 
                                ])
ye = counties_encoded['high_risk']

# %%
Xe_train, Xe_test, ye_train, ye_test = train_test_split(Xe,ye, test_size=.2, random_state=0)

# %% [markdown]
# ## Modeling encoded data with Logistic Regression

# %%
pipe2 = Pipe(steps=[
    ('scaler' , StandardScaler()),
    ('logreg' , LogisticRegression(penalty= 'l1', fit_intercept = True, solver='liblinear'))
])

# %%
pipe2.fit(Xe_train, ye_train)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logreg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l1', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
ye_hat_train_probs = pipe2.predict_proba(Xe_train)
ye_hat_test_probs = pipe2.predict_proba(Xe_test)
ye_hat_train_probs #our probabilities for the encoded data
# Out:
# array([[2.49954553e-02, 9.75004545e-01],
#        [4.36691403e-01, 5.63308597e-01],
#        [9.76024613e-01, 2.39753866e-02],
#        ...,
#        [9.98946471e-01, 1.05352876e-03],
#        [9.99200643e-01, 7.99356981e-04],
#        [9.73861360e-01, 2.61386402e-02]])

# %%
ye_hat_test_1_probs = pipe2.predict_proba(Xe_test)[:,1] #only our 1 probabilities
fpre, tpre, thresholdse = roc_curve(ye_test, ye_hat_test_1_probs)

print(f"Train ROC/AUC Score: {roc_auc_score(ye_train, ye_hat_train_1_probs)}") 
print(f"Test ROC/AUC Score: {roc_auc_score(ye_test, ye_hat_test_1_probs)}")
# Out:
# Train ROC/AUC Score: 0.4928030303030303
# Test ROC/AUC Score: 0.8804460197902821

# %%
#set seaborn styling
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#set figure size
plt.figure(figsize=(10,8))
lw = 3 #linewidth
plt.plot(fpre, tpre, color='orange',
         lw=lw, label='ROC curve (Test Data)') #plot the fpr and tpr 
plt.plot([0, 1], [0, 1], color='gray', lw=lw, linestyle='--') #plot the 50% rating 
plt.xlim([-0.05, 1.0]) #set plot domain
plt.ylim([-0.05, 1.05])#set plot range 
plt.yticks([i/10.0 for i in range(11)], fontsize=15) 
plt.xticks([i/10.0 for i in range(11)], fontsize=15)
plt.xlabel('False Positive Rate', fontsize=20)
plt.ylabel('True Positive Rate', fontsize=20)
plt.title("ROC Curve for Test Data", fontsize=20)
print('AUC: {}'.format(roc_auc_score(ye_test, ye_hat_test_1_probs)))
plt.show()
# Out:
# AUC: 0.8804460197902821

# %%
print(f"ROC/AUC score:{roc_auc_score(ye_test, ye_hat_test_1_probs)}")
print(f"Log Loss:{log_loss(ye_test, ye_hat_test_1_probs)}")
print(f"Accuracy score:{accuracy_score(ye_test, ye_hat_test_1_probs>=.5)}")
print(f"Precision score:{precision_score(ye_test, ye_hat_test_1_probs>=.5)}")
print(f"Recall score:{recall_score(ye_test, ye_hat_test_1_probs>=.5)}")
print(f"f1 score:{f1_score(ye_test, ye_hat_test_1_probs>=.5)}")

pipe2_cv_score = cross_val_score(pipe2, Xe_test, ye_test, cv=5, scoring='roc_auc')
mean_pipe2_cv_score = pipe2_cv_score.mean()
print("Mean Cross Validation ROC/AUC Score: {:.4}%".format(mean_pipe2_cv_score * 100))
# Out:
# ROC/AUC score:0.8804460197902821
# Log Loss:0.209183861108333
# Accuracy score:0.913151364764268
# Precision score:0.5714285714285714
# Recall score:0.21621621621621623
# f1 score:0.3137254901960784
# Mean Cross Validation ROC/AUC Score: 84.09%

# %% [markdown]
# We recommend considering the following thresholds as decision boundaries:

# %%
option_a=-10
option_b=-16
print(f"True positive rate (Option A):{tpre[option_a]*100}%")
print(f"False positive rate (Option A):{fpre[option_a]*100}%")
print(f"Probability decision boundary for these rates (Option A):{thresholdse[option_a]*100}%")
print(f"True positive rate (Option B):{tpre[option_b]*100}%")
print(f"False positive rate (Option B):{fpre[option_b]*100}%")
print(f"Probability decision boundary for these rates (Option B):{thresholdse[option_b]*100}%")
# Out:
# True positive rate (Option A):89.1891891891892%
# False positive rate (Option A):24.59016393442623%
# Probability decision boundary for these rates (Option A):7.129992811415542%
# True positive rate (Option B):81.08108108108108%
# False positive rate (Option B):16.120218579234972%
# Probability decision boundary for these rates (Option B):10.904465455639208%

# %%
plt.figure(figsize=(12,8))
# plt.plot(thresholdse, 1-tpre, color='red', label='False Negative Rate', lw=4)
plt.plot(thresholdse, tpre, color='#66cc00', label='True Positive Rate', lw=4)
plt.plot(thresholdse, fpre, color='#800000', label='False Positive Rate', lw=4)
# plt.plot(thresholdse, 1-fpre, color='green', label='True Negative Rate', lw=4)
plt.xlabel('Threshold: Probability Decision Boundary', fontsize=15)
plt.ylabel('Rate', fontsize=15)
plt.xlim((0,.5))
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/40.0 for i in range(21)])
# plt.axvline(x=thresholdse[-16], lw=3, linestyle='--', color='gray') 
# plt.axvline(x=thresholdse[-10], lw=3, linestyle='--', color='gray')
plt.title('Threshold Options to Consider', fontsize=26)
plt.legend(loc='upper right', fontsize=17, fancybox=True );

# %% [markdown]
# At more than ~8-10% probability that a county will be in that positive class, then we will label them as being at a high overdose rate. Here are those points plotted out:

# %%
#set seaborn styling
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#set figure size
plt.figure(figsize=(10,8))
lw = 3 #linewidth
#MODEL 
plt.plot(fpr, tpr, color='purple',
         lw=lw, label='Model 1 Test ROC')
#MODEL 1 w/ Threshold = 0.2
#fprT, tprT, thresholdsT = roc_curve(y_test, y_hat_test_1_probs>=0.2)
#plt.plot(fprT, (y_hat_test_1_probs>=0.2), color='blue',
#         lw=lw, label='Model 1 Test ROC - Adjusted 0.2')

#################
#MODEL 2
plt.plot(fpre, tpre, color='orange',
         lw=lw, label='Model 2 Test ROC')
#MODEL 2 w/ Threshold = 0.0947
fpreT, tpreT, thresholdseT = roc_curve(ye_test, ye_hat_test_1_probs>=thresholdse[-16])
plt.plot(fpreT, tpreT, color='green',
         lw=lw, label='Model 2 Test ROC - Adjusted 0.0947')

#MODEL 2 w/ Threshold = 0.0516
fpreT2, tpreT2, thresholdseT2 = roc_curve(ye_test, ye_hat_test_1_probs>=thresholdse[-10])
plt.plot(fpreT2, tpreT2, color='red',
         lw=lw, label='Model 2 Test ROC - Adjusted 0.0516')

 #plot the fpr and tpr 
plt.plot([0, 1], [0, 1], color='cyan', lw=lw, linestyle='--') #plot the 50% rating 
plt.xlim([-0.05, 1.0]) #set plot domain
plt.ylim([-0.05, 1.05])#set plot range 
plt.yticks([i/10.0 for i in range(11)]) 
plt.xticks([i/10.0 for i in range(11)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC Curve for Test Data")
plt.legend(loc="upper left")
#print('AUC: {}'.format(roc_auc_score(ye_test, ye_hat_test_1_probs)))
plt.show()

# %%
print(tpre[-16])
print(fpre[-16])
print(thresholdse[-16])
# Out:
# 0.8409090909090909
# 0.21448467966573817
# 0.07341507833739844

# %%
thresholdse[-10]
# Out:
# 0.04886678219723146

# %%
print(f"ROC/AUC score:{roc_auc_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Log Loss:{log_loss(y_test, y_hat_test_1_probs>=.2)} - remember this is to compare models!")
print(f"Accuracy score:{accuracy_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Precision score:{precision_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Recall score:{recall_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"f1 score:{f1_score(y_test, (y_hat_test_1_probs>=.2))}")
# Out:
# ROC/AUC score:0.5900531679220203
# Log Loss:5.142315063051705 - remember this is to compare models!
# Accuracy score:0.8511166253101737
# Precision score:0.23255813953488372
# Recall score:0.2702702702702703
# f1 score:0.25

# %%
#find the coefficients of our logreg
coefficients = pipe2.named_steps.logreg.coef_[0]

# %%
len(coefficients)
# Out:
# 69

# %%
Xe.columns
# Out:
# Index(['%_inschool_3+', '%_preschool_3+', '%_kinderg_3+', '%_elementary_3+',
#        '%_highschool_3+', '%_college_3+', '%_25+', '%_below9th_25+',
#        '%_9th-12th_25+', '%_hsgrad_25+', '%_somecollege_25+',
#        '%_associates_25+', '%_bachelors_b25+', '%_gradschool_25+',
#        '%_hsgrad_or+_25+', '%_bachelors_or+_25+',
#        '%_useinternet_total_households', '%_havecomp_total_households',
#        '%_broadband_total_households', 'state_cols_1.0', 'state_cols_2.0',
#        'state_cols_4.0', 'state_cols_5.0', 'state_cols_6.0', 'state_cols_8.0',
#        'state_cols_9.0', 'state_cols_10.0', 'state_cols_11.0',
#        'state_cols_12.0', 'state_cols_13.0', 'state_cols_15.0',
#        'state_cols_16.0', 'state_cols_17.0', 'state_cols_18.0',
#        'state_cols_19.0', 'state_cols_20.0', 'state_cols_21.0',
#        'state_cols_22.0', 'state_cols_23.0', 'state_cols_24.0',
#        'state_cols_25.0', 'state_cols_26.0', 'state_cols_27.0',
#        'state_cols_28.0', 'state_cols_29.0', 'state_cols_30.0',
#        'state_cols_31.0', 'state_cols_32.0', 'state_cols_33.0',
#        'state_cols_34.0', 'state_cols_35.0', 'state_cols_36.0',
#        'state_cols_37.0', 'state_cols_38.0', 'state_cols_39.0',
#        'state_cols_40.0', 'state_cols_41.0', 'state_cols_42.0',
#        'state_cols_44.0', 'state_cols_45.0', 'state_cols_46.0',
#        'state_cols_47.0', 'state_cols_48.0', 'state_cols_49.0',
#        'state_cols_50.0', 'state_cols_51.0', 'state_cols_53.0',
#        'state_cols_54.0', 'state_cols_55.0'],
#       dtype='object')

# %%
plt.plot(Xe.columns, coefficients)

# %%
feature_impacts = zip(list(Xe.columns), list(coefficients))
feature_impacts = set(feature_impacts)

# %%
coef_df = pd.DataFrame(feature_impacts, columns=['feature', 'coefficient'])

# %%
abs(coef_df['Coefficient'][0])
# Out:
# 0.0

# %%
ordered_df = coef_df.reindex(coef_df.coefficient.abs().sort_values(ascending=False).index)
ordered_df
# Out:
#                            feature  coefficient
# 24                 state_cols_48.0    -0.875983
# 64    %_broadband_total_households    -0.834369
# 7                   %_9th-12th_25+     0.750014
# 15               %_somecollege_25+     0.733234
# 18                 state_cols_13.0    -0.733061
# 20                 state_cols_28.0    -0.677833
# 27                 state_cols_45.0    -0.553246
# 39                  %_below9th_25+    -0.544092
# 13                 state_cols_22.0    -0.491429
# 42                  state_cols_5.0    -0.459390
# 56                 state_cols_54.0     0.437256
# 57                 state_cols_39.0     0.431791
# 35     %_havecomp_total_households    -0.416011
# 38                %_gradschool_25+     0.410403
# 40                 state_cols_42.0     0.394337
# 3                  state_cols_21.0     0.348170
# 59                 state_cols_55.0    -0.328878
# 58                  state_cols_8.0     0.314664
# 19                 state_cols_20.0    -0.297160
# 53                 state_cols_35.0     0.271294
# 49                  state_cols_6.0     0.264130
# 63                 state_cols_47.0     0.252061
# 29                 state_cols_53.0     0.240606
# 1                   state_cols_1.0    -0.238797
# 67                  state_cols_4.0     0.236724
# 14                 state_cols_41.0     0.235367
# 25                 state_cols_17.0    -0.222501
# 61                 state_cols_25.0     0.210058
# 44                 state_cols_29.0    -0.206887
# 65                 state_cols_33.0     0.202916
# ..                             ...          ...
# 8                  state_cols_16.0     0.106830
# 41                  state_cols_2.0     0.099936
# 43                 state_cols_26.0    -0.097971
# 6                  state_cols_32.0     0.082631
# 47                 state_cols_24.0     0.070925
# 28                 state_cols_49.0     0.069929
# 51                 %_highschool_3+    -0.065749
# 17                 state_cols_18.0     0.063577
# 2                    %_inschool_3+    -0.058271
# 12                 state_cols_46.0     0.048272
# 55                 state_cols_50.0    -0.042054
# 5                     %_kinderg_3+     0.041775
# 23                 state_cols_30.0     0.039369
# 10                 state_cols_31.0     0.031564
# 45                 state_cols_27.0    -0.029446
# 46                %_associates_25+    -0.020727
# 21                 state_cols_34.0    -0.011730
# 66                 %_elementary_3+    -0.002604
# 68                 state_cols_11.0    -0.001438
# 11                 state_cols_10.0     0.000000
# 30                %_bachelors_b25+     0.000000
# 36             %_bachelors_or+_25+     0.000000
# 37                %_hsgrad_or+_25+     0.000000
# 48                 state_cols_15.0     0.000000
# 50                 state_cols_44.0     0.000000
# 4                     %_hsgrad_25+     0.000000
# 52                    %_college_3+     0.000000
# 54  %_useinternet_total_households     0.000000
# 62                           %_25+     0.000000
# 0                   state_cols_9.0     0.000000
#
# [69 rows x 2 columns]

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import sklearn

# %%
rf = RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=7)

# %%
rf.fit(Xe_train,ye_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#             oob_score=False, random_state=7, verbose=0, warm_start=False)

# %%
yerf_hat_test_probs = rf.predict_proba(Xe_test)
yerf_hat_train_probs = rf.predict_proba(Xe_train)

# %%
yerf_hat_test_1_probs = yerf_hat_test_probs[:,1]
fprerf, tprerf, thresholdserf = roc_curve(ye_test, yerf_hat_test_1_probs)

yerf_hat_train_1_probs = yerf_hat_train_probs[:,1]

print(f"Train ROC/AUC Score: {roc_auc_score(ye_train, yerf_hat_train_1_probs)}")
print(f"Test ROC/AUC Score: {roc_auc_score(ye_test, yerf_hat_test_1_probs)}")
rf_cv_score = cross_val_score(rf, Xe_test, ye_test, cv=5, scoring='roc_auc')
mean_rf_cv_score = rf_cv_score.mean()
print("Mean Cross Validation ROC/AUC Score: {:.4}%".format(mean_rf_cv_score * 100))
# Out:
# Train ROC/AUC Score: 1.0
# Test ROC/AUC Score: 0.823559858726099
# Mean Cross Validation ROC/AUC Score: 75.31%

# %%
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'brier_score_loss',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'mutual_info_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'v_measure_score']

# %%
#PLOT
#set seaborn styling
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#set figure size
plt.figure(figsize=(10,8))
lw = 3 #linewidth
#MODEL 1 - LOGISTIC
plt.plot(fpr, tpr, color='purple',
         lw=lw, label='Model 1 Test ROC - Logistic')

#MODEL 2 - LOGISTIC ENCODED
plt.plot(fpre, tpre, color='orange',
         lw=lw, label='Model 2 Test ROC - Logistic Encoded')

#MODEL 3 - RANDOM FOREST ENCODED
plt.plot(fprerf, tprerf, color='green',
         lw=lw, label='Model 3 Test ROC - RF Encoded')

#plot the fpr and tpr 
plt.plot([0, 1], [0, 1], color='cyan', lw=lw, linestyle='--') #plot the 50% rating 
plt.xlim([-0.05, 1.0]) #set plot domain
plt.ylim([-0.05, 1.05])#set plot range 
plt.yticks([i/10.0 for i in range(11)]) 
plt.xticks([i/10.0 for i in range(11)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC Curve for Test Data")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## GridSearch on Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_param_grid = {'criterion':['gini','entropy'],
                 'max_depth': [4, 5, 6, 10],
                 'min_samples_split': [2, 5, 10],
                 'min_samples_leaf': [1, 2, 3, 4, 5, 6]
}

# %%
rf_grid_search = GridSearchCV(rf, param_grid=rf_param_grid, cv=5, scoring='roc_auc')

# %%
#rf_grid_search.fit(Xe_train, ye_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#             oob_score=False, random_state=7, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [4, 5, 6, 10], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 3, 4, 5, 6]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
rf_grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %%
rf_grid_optimal = RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=7, criterion='entropy',
                                        max_depth=10, min_samples_leaf=6, min_samples_split=2)

# %%
rf_grid_optimal.fit(Xe_train,ye_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=6, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#             oob_score=False, random_state=7, verbose=0, warm_start=False)

# %%
yerfgo_hat_test_probs = rf_grid_optimal.predict_proba(Xe_test)
yerfgo_hat_train_probs = rf_grid_optimal.predict_proba(Xe_train)

# %%
yerfgo_hat_test_1_probs = yerfgo_hat_test_probs[:,1]
fprerfgo, tprerfgo, thresholdserfgo = roc_curve(ye_test, yerfgo_hat_test_1_probs)

yerfgo_hat_train_1_probs = yerfgo_hat_train_probs[:,1]

print(f"Train ROC/AUC Score: {roc_auc_score(ye_train, yerfgo_hat_train_1_probs)}")
print(f"Test ROC/AUC Score: {roc_auc_score(ye_test, yerfgo_hat_test_1_probs)}")

rfgo_cv_score = cross_val_score(rf_grid_optimal, Xe_test, ye_test, cv=5, scoring='roc_auc')
mean_rfgo_cv_score = rfgo_cv_score.mean()
print("Mean Cross Validation ROC/AUC Score: {:.4}%".format(mean_rfgo_cv_score * 100))
# Out:
# Train ROC/AUC Score: 0.9719823580873121
# Test ROC/AUC Score: 0.8075752039946412
# Mean Cross Validation ROC/AUC Score: 67.46%

# %%
ye_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6dcdd00b8bc8> in <module>
# ----> 1 ye_test
#
# NameError: name 'ye_test' is not defined

# %%
#save for lateR: 
print(f"ROC/AUC score:{roc_auc_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Log Loss:{log_loss(y_test, y_hat_test_1_probs>=.2)} - remember this is to compare models!")
print(f"Accuracy score:{accuracy_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Precision score:{precision_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"Recall score:{recall_score(y_test, (y_hat_test_1_probs>=.2))}")
print(f"f1 score:{f1_score(y_test, (y_hat_test_1_probs>=.2))}")
# Out:
# ROC/AUC score:0.6380563124432334
# Log Loss:3.8567288568660425 - remember this is to compare models!
# Accuracy score:0.8883374689826302
# Precision score:0.36363636363636365
# Recall score:0.3333333333333333
# f1 score:0.34782608695652173
